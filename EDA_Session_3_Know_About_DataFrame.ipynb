# %% [markdown]
# **Import required packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Read the data**

# %% [markdown]
# **Note:**
#
# - visa_df is dataframe type
#
# - visa_df.values is : **series**
#
# - series means a key value pair

# %%
visa_df=pd.read_csv(r"C:\Users\animi\OneDrive\NareshIT\DataFiles\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $head$
#
# - It will give default **Top 5 rows**
#
# - If we need some particular number then we can give number

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.head(10)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %% [markdown]
# $tail$
#
# - It will give **Last 5 rows**
#
# - If we need some particular number then we can give number

# %%
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_df.tail(6)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25474                     N             2594         1979
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
# ...

# %% [markdown]
# $shape$
#
# - number of rows and number of columns

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
print(f"The number of rows are {visa_df.shape[0]}")
print(f"The number of columns are {visa_df.shape[1]}")
# Out:
# The number of rows are 25480
# The number of columns are 12

# %% [markdown]
# $size$
#
# - number of rows*number of columns
#
# - Gives how many recors are there

# %%
visa_df.size
# Out:
# 305760

# %%
25480*12
# Out:
# 305760

# %% [markdown]
# $columns$
#
# - Gives the column names

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# $dtypes$
#
# - data types

# %%
visa_df.dtypes

# object - categorical
# int, float - numerical
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# **Note:**
#
# - visa_df is dataframe type
#
# - visa_df.values is : **series**
#
# - series means a key value pair
#
# - series object can convert into dictionary
#
# - after that you can use dictionary methods

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Task**
#
# - convert categorical list
#
# - create numerical column list
#
# **idea**
#
# - convert series type into dictionary
#
# - iterate through loop
#
# - apply the condition get the result in the list

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
dtypes=dict(visa_df.dtypes) # converting series to dictionary
dtypes
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
for key,value in dtypes.items():
    if value in ['object']:
        print(key,value)
# Out:
# case_id object
# continent object
# education_of_employee object
# has_job_experience object
# requires_job_training object
# region_of_employment object
# unit_of_wage object
# full_time_position object
# case_status object

# %%
for key,value in dtypes.items():
    if value not in ['object']:
        print(key,value)
# Out:
# no_of_employees int64
# yr_of_estab int64
# prevailing_wage float64

# %%
categorical_cols=[key for key,value in dtypes.items() if value =='object']
categorical_cols
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
numerical_cols=[key for key,vale in dtypes.items() if value!='object']
numerical_cols
# Out:
# []

# %% [markdown]
# $select$-$data$-$types$
#
# - select data types will give a data frame of desired data types
#
# - the result also a data frame
#
# - all above options like head tail columns

# %%
visa_df.select_dtypes(include='object')
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# 0                         N                 West         Hour
# ...

# %%
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# $is$-$null$:
#
# - is nulll used to identify the any missing values are available or null values
#
# - is null means we are asking a question to the computer
#
# - it will give true or false
#
# - True : yes values is missed
#
# - False : No Value is not missed

# %% [markdown]
# **Note**
#
# - If we see bound method means we need to add the brackets()

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %% [markdown]
# visa_df.isnull().sum()

# %%
visa_df.isna()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %% [markdown]
# $drop$-$duplicates$
#
# - If any duplicates are there then we can drop it

# %%
visa_df.drop_duplicates()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.drop_duplicates().all()
# Out:
# case_id                  True
# continent                True
# education_of_employee    True
# has_job_experience       True
# requires_job_training    True
# no_of_employees          True
# yr_of_estab              True
# region_of_employment     True
# prevailing_wage          True
# unit_of_wage             True
# full_time_position       True
# case_status              True
# dtype: bool

# %% [markdown]
# $info$

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# $take$
#
# - take is used to extract the particular index of data
#
# - take has 1 parameter called axis
#
# - axis=1 represents columns
#
# - axis=0 represents rows
#
# - by default axis=0 is there
#
# - In below example we given 100,200,300 and we did not provided axis value
#
# - It understood we are taking about rows

# %%
visa_df.take([100,200,300])
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.take([100,200,300], axis=1) # we dont have columns with 100, 200 and 300 so its not working
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 visa_df.take([100,200,300], axis=1)
#
# File C:\Users\Alekhya\Lib\site-packages\pandas\core\generic.py:4068, in NDFrame.take(self, indices, axis, **kwargs)
#    4063     # We can get here with a slice via DataFrame.__getitem__
#    4064     indices = np.arange(
#    4065         indices.start, indices.stop, indices.step, dtype=np.intp
#    4066     )
# -> 4068 new_data = self._mgr.take(
#    4069     indices,
#    4070     axis=self._get_block_manager_axis(axis),
#    4071     verify=True,
#    4072 )
#    4073 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4074     self, method="take"
#    4075 )
#
# File C:\Users\Alekhya\Lib\site-packages\pandas\core\internals\managers.py:874, in BaseBlockManager.take(self, indexer, axis, verify)
# ...

# %%
visa_df.take([2,5,7], axis=1) # it is giving columns
# Out:
#       education_of_employee  no_of_employees region_of_employment
# 0               High School            14513                 West
# 1                  Master's             2412            Northeast
# 2                Bachelor's            44444                 West
# 3                Bachelor's               98                 West
# 4                  Master's             1082                South
# ...                     ...              ...                  ...
# 25475            Bachelor's             2601                South
# 25476           High School             3274            Northeast
# 25477              Master's             1121                South
# 25478              Master's             1918                 West
# 25479            Bachelor's             3195              Midwest
#
# [25480 rows x 3 columns]

# %%
visa_df.take([100:105]) # not working, slicing not work with take
# Out:
#   Cell In[104], line 1
#     visa_df.take([100:105]) # not working, slicing not work with take
#                      ^
# SyntaxError: invalid syntax

# %%
# Q)
# If I want rows 100 200 300 and columns : 2,5,7
# with single syntax (with single take) it is not possible
# So that is the drawback of take
# Slicing is not poosible in take

# %%
visa_df.take([100,200,300]).take([2,5,7],axis=1)
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 200             Doctorate             3282                 West
# 300              Master's             3268              Midwest

# %% [markdown]
# $iloc$
#
# **visa_df.iloc[<rows>,<columns>]**
#
# **visa_df.iloc[<start:end>,<start:end>]**
#
# - we can overcome drawback of take with iloc
#
# - We can get both rows and columns retrieval at a time is possible
#
# - Slicing is possible
#
# - **Note**
#
#     - No bracket, then it is series
#
#     - with bracket then dataframe

# %%
visa_df.iloc[[100,200,300],[2,5,7]]
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 200             Doctorate             3282                 West
# 300              Master's             3268              Midwest

# %%
visa_df.iloc[[100,200,300]] # same like take
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.iloc[100:105,[2,5,7]]
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 101              Master's              334              Midwest
# 102            Bachelor's              224              Midwest
# 103             Doctorate              367                 West
# 104              Master's              306            Northeast

# %%
visa_df.iloc[100:105,2:6]
# Out:
#     education_of_employee has_job_experience requires_job_training  \
# 100              Master's                  Y                     N
# 101              Master's                  Y                     N
# 102            Bachelor's                  Y                     N
# 103             Doctorate                  Y                     N
# 104              Master's                  Y                     N
#
#      no_of_employees
# 100             2227
# 101              334
# 102              224
# 103              367
# 104              306

# %%
visa_df.iloc[100:105,[2]]
# Out:
#     education_of_employee
# 100              Master's
# 101              Master's
# 102            Bachelor's
# 103             Doctorate
# 104              Master's

# %%
visa_df.iloc[[100],:] # one row with all columns
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
visa_df.iloc[[100],0:] # one row with all columns
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
visa_df.iloc[[100],:] # one row with all columns
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
visa_df.iloc[[100]] # one row with all columns
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
# How to get only number of employees
visa_df.iloc[:,[5]] # 5 is index of no_of_employees
# Out:
#        no_of_employees
# 0                14513
# 1                 2412
# 2                44444
# 3                   98
# 4                 1082
# ...                ...
# 25475             2601
# 25476             3274
# 25477             1121
# 25478             1918
# 25479             3195
#
# [25480 rows x 1 columns]

# %%
type(visa_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
cols=list(visa_df.columns)
cols.index('no_of_employees')
# Out:
# 5

# %% [markdown]
# $loc$
#
# - loc will take directly the column names

# %%
visa_df.loc[[100,200,300],['no_of_employees','continent']]
# Out:
#      no_of_employees continent
# 100             2227      Asia
# 200             3282      Asia
# 300             3268      Asia

# %%
visa_df.loc[[100,200,300],['no_of_employees']]
